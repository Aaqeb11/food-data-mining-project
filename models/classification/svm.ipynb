# %% [markdown]
# # Classification using SVM

# %%
import pandas as pd

df = pd.read_csv('../../data/output/restaurant_foods_macros.csv')

df.head()
# Out:
# /var/folders/01/2pvpvp5d5fq1k0dzwssl_2pw0000gn/T/ipykernel_26339/486638922.py:3: DtypeWarning: Columns (4,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../../data/output/restaurant_foods_macros.csv')
#     fdc_id                                  description     data_type  \
# 0  1105906     CAMPBELL'S SLOW KETTLE SOUP CLAM CHOWDER  branded_food
# 1  1105907  CAMPBELL'S SLOW KETTLE SOUP CHEESE BROCCOLI  branded_food
# 2  1105909                 CAMPBELL'S SOUP BEAN AND HAM  branded_food
# 3  1105912                       CAMPBELL'S SOUP TOMATO  branded_food
# 4  1105913        CAMPBELL'S PASTA SPAGHETTIOS W FRANKS  branded_food
#
#   cooking_method category_name  calories_final  protein   fat  carbohydrate  \
# 0        unknown           NaN            82.0     2.45  5.31          6.12
# 1        unknown           NaN            82.0     1.22  6.12          5.31
# ...
